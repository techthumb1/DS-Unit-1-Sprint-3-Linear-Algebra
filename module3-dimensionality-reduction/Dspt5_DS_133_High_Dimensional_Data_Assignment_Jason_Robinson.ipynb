# %% [markdown]
# <a href="https://colab.research.google.com/github/techthumb1/DS-Unit-1-Sprint-3-Linear-Algebra/blob/master/module3-dimensionality-reduction/Jason_Robinson_DS_133_High_Dimensional_Data_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vertical Line Test

# %% [markdown]
# ## 1.1 Create two graphs, one that passes the vertical line test and one that does not.

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size':14})

# %%
#Plot the passes the vertical line test
x = np.arange(-17,18)
y = x**4 + 6*x
plt.plot(x,y)
plt.axvline(x=0, color='magenta');

# %%
#A vertical line that does not pass the test
y = np.arange(-4,5)
x = y**9 + 3*y
plt.plot(x,y)
plt.axvline(x=0, color='magenta');

# %%
#A better example of a vertical test failure
theta = np.arange(0, 8*np.pi, 0.1)
for c in np.arange(2, 4):
  x = 1*np.sin(theta+c)*np.exp(.4*theta)
  y = 1*np.cos(theta+c)*np.exp(.4*theta)
  pl = plt.plot(x,y)
plt.axvline(x=.5, color='red');

# %% [markdown]
# ## 1.2 Why are graphs that don't pass the vertical line test not considered "functions?"

# %% [markdown]
# They are not considered functions because regarding domain value and range value relationships, each domain values can only relate to one range value. So for a domain that is mapped to several different range values, it cannot be thought of as a full function. Possibly a partial function, or a multi-valued function.

# %% [markdown]
# # Functions as Relations

# %% [markdown]
# ## 2.1 Which of the following relations are functions? Why?
#
# \begin{align}
# \text{Relation 1: } \{(1, 2), (3, 2), (1, 3)\}
# \\
# \text{Relation 2: } \{(1, 3), (2, 3), (6, 7)\}
# \\
# \text{Relation 3: } \{(9, 4), (2, 1), (9, 6)\}
# \\
# \text{Relation 4: } \{(6, 2), (8, 3), (6, 4)\}
# \\
# \text{Relation 5: } \{(2, 6), (2, 7), (2, 4)\}
# \end{align}

# %%
#Only one of the relations is a function and that is Realtion 2, the other 
#relations are not functions because the domain values are not mapping to a single range value.
#Will use the vertical line test to for assurance on the five relations
x = np.array([1, 3 ,1])
y = np.array([2, 2, 3])
plt.scatter(x, y, s=100)
plt.plot(x, y, color='b')
plt.title('Relation: 1');
#Relation 1

# %%
x = np.array([1, 2, 6])
y = np.array([3, 3, 7])
plt.scatter(x, y, s=100, color='g')
plt.plot(x, y, color='g')
plt.title('Relation: 2');

# %%
x = np.array([9, 2 ,9])
y = np.array([4, 1, 6])
plt.scatter(x, y, s=100, color='r')
plt.plot(x, y, color='r')
plt.title('Relation: 3');

# %%
x = np.array([6, 8 ,6])
y = np.array([2, 3, 4])
plt.scatter(x, y, s=100, color='y')
plt.plot(x, y, color='y')
plt.title('Relation: 4');

# %%
x = np.array([2, 2 ,6])
y = np.array([6, 7, 4])
plt.scatter(x, y, s=100, color='purple')
plt.plot(x, y, color='purple')
plt.title('Relation: 5');

# %% [markdown]
# # Functions as a mapping between dimensions

# %% [markdown]
# ## 3.1 for the following functions what is the dimensionality of the domain (input) and codomain (range/output)?
#
# \begin{align}
# m(𝑥_1,𝑥_2,𝑥_3)=(x_1+x_2, x_1+x_3, x_2+x_3)
# \\
# n(𝑥_1,𝑥_2,𝑥_3,𝑥_4)=(x_2^2 + x_3, x_2x_4)
# \end{align}

# %%
#The dimensionality of the domain in the first function is R**3, in the 
#second one another dimension is added R**4

# %% [markdown]
# ## 3.2 Do you think it's possible to create a function that maps from a lower dimensional space to a higher dimensional space? If so, provide an example.

# %%
#Yes it is possible

# %% [markdown]
# # Vector Transformations

# %% [markdown]
# ## 4.1 Plug the corresponding unit vectors into each function. Use the output vectors to create a transformation matrix.
#
# \begin{align}
# p(\begin{bmatrix}x_1 \\ x_2 \end{bmatrix}) = \begin{bmatrix} x_1 + 3x_2 \\2 x_2 - x_1 \\  \end{bmatrix}
# \\
# \\
# q(\begin{bmatrix}x_1 \\ x_2 \\ x_3\end{bmatrix}) = \begin{bmatrix} 4x_1 + x_2 + 2x_3 \\2 x_2 - x_1 + 3x_3 \\ 5x_1 - 2x_3 + x_2  \end{bmatrix}
# \end{align}

# %%
def p(vect):
  x1=vect[0][0]
  x2=vect[1][0]
  output_row1=np.array([x1 + 3 * x2])
  output_row2=np.array([2 * x2 - x1])
  output_vector=np.array([output_row1, output_row2])
  return output_vector

def q(vect):
  x1=vect[0][0]
  x2=vect[1][0]
  x3=vect[2][0]
  output_row1=np.array([4*x1 + x2 + 2*x3])
  output_row2=np.array([2*x2 + x1 + 3*x3])
  output_row3=np.array([5*x1 - 2*x3 + x2])
  output_vector=np.array([output_row1, output_row2, output_row3])
  return output_vector

# %% [markdown]
# ## 4.2 Verify that your transformation matrices are correct by choosing an input matrix and calculating the result both via the traditional functions above and also via vector-matrix multiplication.

# %%
#Apply p to x axis unit vector
i_hat = np.array([[1],[0]])
a=p(i_hat)
a
# Out:
# array([[ 1],
#        [-1]])

# %%
#Apply p to y axis unit vector
j_hat = np.array([[0],[1],[2]])
b=p(j_hat)
b
# Out:
# array([[3],
#        [2]])

# %%
#Create a matrix out of the unit vectors
T = np.column_stack([a,b])
T
# Out:
# array([[ 1,  3],
#        [-1,  2]])

# %%
#Create a df out of the matrix for comparison
pd.DataFrame(T)
# Out:
#    0  1
# 0  1  3
# 1 -1  2

# %%
input_vector = np.array([[]])

# %% [markdown]
# # Eigenvalues and Eigenvectors

# %% [markdown]
# ## 5.1 In your own words, give an explanation for the intuition behind eigenvalues and eigenvectors.

# %%
#In vector transformation, eigenvalues are the difference in value for the change a eigenvectors has after transformation. 
#Eigenvectors can transform but they do not change direction.

# %% [markdown]
# # The Curse of Dimensionality

# %% [markdown]
# ## 6.1 What are some of the challenges of working with high dimensional spaces?

# %% [markdown]
# The problems with high dimensional spaces:
# *   Working with extremely large number of features
# *   More difficult to explore the data and create visualizations
# *   Increased redundacy
# *   Increased computational workload
# *   Risk of overfitting

# %% [markdown]
# # 6.2 What is the rule of thumb for how many observations you should have compared to parameters in your model?
#
# For rule of thumb, one should always make sure that they have 5 times the number of observations as the number of parameters.
#
# However, others say that the number of observations should be the square of the number of parameters.

# %% [markdown]
# # Principal Component Analysis

# %% [markdown]
# ## 7.1 Code for loading and cleaning the 2013 national dataset from the [Housing Affordability Data System (HADS)](https://www.huduser.gov/portal/datasets/hads/hads.html) --housing data, can be found below.
#
# ## Perform PCA on the processed dataset `national_processed` (Make sure you standardize your data!) and then make a scatterplot of PC1 against PC2. Some of our discussion and work around PCA with this dataset will continue during tomorrow's lecture and assignment.
#
# Not only does this dataset have decent amount columns to begin with (99), but in preparing the data for PCA we have also [one-hot-encoded](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f#targetText=One%20hot%20encoding%20is%20a,the%20entry%20in%20the%20dataset.) all of the categorical variables. This has the effect of creating a new column for each individual category of each categorical variable. After processing this dataset has 64738 columns. --Das a lot of columns.
#
# Don't worry too much about the mechanics of one-hot encoding right now, you will learn and experiment with a whole bunch of categorical encoding approaches in unit 2.
#
# The code below will read in the dataset and perform the one-hot encoding of the categorical variables. Start adding your PCA code at the bottom of the provided code.

# %%
from urllib.request import urlopen
from zipfile import ZipFile
from io import BytesIO
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read National Data 
national_url = 'https://www.huduser.gov/portal/datasets/hads/hads2013n_ASCII.zip'
national_file = 'thads2013n.txt'

if os.path.exists(national_file):
    national = pd.read_csv(national_file)
else: 
    z_national = urlopen(national_url)
    zip_national = ZipFile(BytesIO(z_national.read())).extract(national_file)
    national = pd.read_csv(zip_national)

print(national.shape)
national.head()
# Out:
# (64535, 99)
#           CONTROL  AGE1 METRO3 REGION   LMED   FMR    L30    L50    L80  \
# 0  '100003130103'    82    '3'    '1'  73738   956  15738  26213  40322
# 1  '100006110249'    50    '5'    '3'  55846  1100  17165  28604  45744
# 2  '100006370140'    53    '5'    '3'  55846  1100  13750  22897  36614
# 3  '100006520140'    67    '5'    '3'  55846   949  13750  22897  36614
# 4  '100007130148'    26    '1'    '3'  60991   737  14801  24628  39421
#
#     IPOV  ...      FMTINCRELFMRCAT  FMTCOST06RELAMICAT FMTCOST08RELAMICAT  \
# 0  11067  ...      '1 LTE 50% FMR'    '2 30 - 50% AMI'   '2 30 - 50% AMI'
# 1  24218  ...           '3 GT FMR'    '4 60 - 80% AMI'   '4 60 - 80% AMI'
# 2  15470  ...  '2 50.1 - 100% FMR'    '4 60 - 80% AMI'  '5 80 - 100% AMI'
# 3  13964  ...  '2 50.1 - 100% FMR'  '6 100 - 120% AMI'     '7 120% AMI +'
# 4  15492  ...           '3 GT FMR'    '3 50 - 60% AMI'   '3 50 - 60% AMI'
#
#    FMTCOST12RELAMICAT  FMTCOSTMEDRELAMICAT   FMTINCRELAMICAT  \
# ...

# %%
# Look at datatypes
# a lot of object datatypes even though they seem to be strings of numbers.
national.dtypes
# Out:
# CONTROL            object
# AGE1                int64
# METRO3             object
# REGION             object
# LMED                int64
#                     ...
# FMTINCRELAMICAT    object
# FMTASSISTED        object
# FMTBURDEN          object
# FMTREGION          object
# FMTSTATUS          object
# Length: 99, dtype: object

# %%
# check for null values
national.isnull().sum().any()
# Out:
# False

# %%
# check for number of categorical vs numeric columns
cat_cols = national.columns[national.dtypes=='object']
num_cols = national.columns[national.dtypes!='object']

print(f'{len(cat_cols)} categorical columns')
print(f'{len(num_cols)} numerical columns')
# Out:
# 32 categorical columns
# 67 numerical columns

# %%
# We're making a copy of our data in case we mess something up.
national_processed = national.copy()

# Categorically Encode our Variables:
# They need to all be numeric before we do PCA.
# https://pbpython.com/categorical-encoding.html

# Cast categorical columns to "category" data type
national_processed[cat_cols] = national_processed[cat_cols].astype('category')

national_processed.dtypes
# Out:
# CONTROL            category
# AGE1                  int64
# METRO3             category
# REGION             category
# LMED                  int64
#                      ...
# FMTINCRELAMICAT    category
# FMTASSISTED        category
# FMTBURDEN          category
# FMTREGION          category
# FMTSTATUS          category
# Length: 99, dtype: object

# %%
# Replace all category cell values with their numeric category codes
for col in cat_cols:
  national_processed[col] = national_processed[col].cat.codes

print(national_processed.shape)
national_processed.head()
# Out:
# (64535, 99)
#    CONTROL  AGE1  METRO3  REGION   LMED   FMR    L30    L50    L80   IPOV  \
# 0        0    82       2       0  73738   956  15738  26213  40322  11067
# 1        1    50       4       2  55846  1100  17165  28604  45744  24218
# 2        2    53       4       2  55846  1100  13750  22897  36614  15470
# 3        3    67       4       2  55846   949  13750  22897  36614  13964
# 4        4    26       0       2  60991   737  14801  24628  39421  15492
#
#    ...  FMTINCRELFMRCAT  FMTCOST06RELAMICAT  FMTCOST08RELAMICAT  \
# 0  ...                1                   1                   1
# 1  ...                3                   3                   3
# 2  ...                2                   3                   4
# 3  ...                2                   5                   6
# 4  ...                3                   2                   2
#
#    FMTCOST12RELAMICAT  FMTCOSTMEDRELAMICAT  FMTINCRELAMICAT  FMTASSISTED  \
# ...

# %%
national_processed['CONTROL'].replace(0,1)
# Out:
# 0            1
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 64530    64530
# 64531    64531
# 64532    64532
# 64533    64533
# 64534    64534
# Name: CONTROL, Length: 64535, dtype: int32

# %%
# Now we only have numeric columns (ints and floats)
national_processed.dtypes
# Out:
# CONTROL            int32
# AGE1               int64
# METRO3              int8
# REGION              int8
# LMED               int64
#                    ...
# FMTINCRELAMICAT     int8
# FMTASSISTED         int8
# FMTBURDEN           int8
# FMTREGION           int8
# FMTSTATUS           int8
# Length: 99, dtype: object

# %%
#Begin with standardizing the data
from sklearn.preprocessing import StandardScaler
feature_cols=national_processed.columns[1:]
feature_cols[:5]
# Out:
# Index(['AGE1', 'METRO3', 'REGION', 'LMED', 'FMR'], dtype='object')

# %%
#Normalize the features
x = national_processed.loc[:,feature_cols].values
x = StandardScaler().fit_transform(x)
x
# Out:
# array([[ 1.48807451,  0.60878419, -1.32787201, ...,  0.54947295,
#         -0.46210707,  0.        ],
#        [ 0.08881241,  2.18426992,  0.57669794, ..., -0.54470863,
#         -0.46210707,  0.        ],
#        [ 0.21999323,  2.18426992,  0.57669794, ...,  1.64365453,
#         -0.46210707,  0.        ],
#        ...,
#        [-1.09181499, -0.17895868,  1.52898291, ...,  1.64365453,
#          2.16400067,  0.        ],
#        [ 0.39490099, -0.96670154,  1.52898291, ..., -0.54470863,
#          2.16400067,  0.        ],
#        [ 0.78844346,  1.39652706,  0.57669794, ..., -0.54470863,
#         -0.46210707,  0.        ]])

# %%
#Check whether the data is normalized
print('{:.2f}'.format(np.mean(x)))
np.std(x)
# Out:
# 0.00
# 0.9948848769417227

# %%
#Convert the normalized features into a dataframe
normal_national  = pd.DataFrame(x, columns=feature_cols)
normal_national.sample(5)
# Out:
#            AGE1    METRO3    REGION      LMED       FMR       L30       L50  \
# 630    1.007078  2.184270 -0.375587 -0.755128 -0.800259 -0.772510 -0.772927
# 24810 -0.173549  2.184270 -0.375587 -1.347153 -0.457721  0.248985  0.247871
# 17457  1.094532 -0.966702  0.576698 -0.949128 -0.267422 -0.937543 -0.940202
# 1246   0.088812 -0.178959  0.576698 -0.650690  0.298401 -0.636971 -0.637378
# 17376 -0.829453 -0.966702  0.576698  0.411464 -0.290258  0.954147  0.957069
#
#             L80      IPOV    BEDRMS  ...  FMTINCRELFMRCAT  FMTCOST06RELAMICAT  \
# 630   -0.766180 -0.282378  0.310570  ...        -0.082759            0.024966
# 24810  0.369947  2.209854  1.224839  ...        -0.082759            0.515887
# 17457 -0.950382 -0.277391  1.224839  ...        -0.082759            0.024966
# 1246  -0.615530 -0.068517  0.310570  ...         0.926091            0.515887
# 17376  1.159945  1.035418 -0.603700  ...        -0.082759            0.024966
#
# ...

# %%
#Find the covariance matrix
covariance_matrix = np.cov(normal_national.T)
covariance_matrix
# Out:
# array([[ 1.0000155 ,  0.07690262, -0.03859443, ...,  0.3103764 ,
#         -0.00355557,  0.        ],
#        [ 0.07690262,  1.0000155 ,  0.08188793, ..., -0.08677012,
#         -0.05644554,  0.        ],
#        [-0.03859443,  0.08188793,  1.0000155 , ..., -0.02321949,
#          0.70656475,  0.        ],
#        ...,
#        [ 0.3103764 , -0.08677012, -0.02321949, ...,  1.0000155 ,
#          0.02305213,  0.        ],
#        [-0.00355557, -0.05644554,  0.70656475, ...,  0.02305213,
#          1.0000155 ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
# Import the PCA model
from sklearn.decomposition import PCA

# %%
# Instanstiate the sklearn class & pass the desired number of components that I
#want to keep out of the dataset
pca_national = PCA(n_components=2)

# %%
# Use fit_transform on the data
pca_data = pca_national.fit_transform(x)
print(pca_data.shape)
pca_data
# Out:
# (64535, 2)
# array([[-2.60748434, -1.38033153],
#        [ 2.01031327, -0.99201858],
#        [ 1.18484923,  0.3662193 ],
#        ...,
#        [ 1.86214169, -2.95179568],
#        [-4.99538419, -2.52488091],
#        [-9.86785674, -0.79890106]])

# %%
# Create a dataframe with principal component values for all features
df_final=pd.DataFrame(data=pca_data, columns=['comp_1','comp_2'])
df_final.head()
# Out:
#      comp_1    comp_2
# 0 -2.607484 -1.380332
# 1  2.010313 -0.992019
# 2  1.184849  0.366219
# 3  2.791772  1.719967
# 4 -1.600407 -0.882243

# %%
#How much variation did each princpal change
pca_national.explained_variance_ratio_
# Out:
# array([0.34391213, 0.14590979])

# %%
#How much total variance did we explain?
sum(pca_national.explained_variance_ratio_)
# Out:
# 0.48982192040999606

# %%
#How much information did we lose?
1-sum(pca_national.explained_variance_ratio_)
# Out:
# 0.5101780795900039

# %%
#Add the control(target) back into the dataframe
df_final['CONTROL']=national_processed['CONTROL']
df_final.sample(5)
# Out:
#          comp_1    comp_2  CONTROL
# 49960  2.995207  1.267214    49960
# 52924  4.083242 -0.897065    52924
# 22677  2.739530 -0.741525    22677
# 31465 -4.076067 -0.197675    31465
# 34709  2.294913  0.593443    34709

# %%
#Generate a visualization of the data of the components
plt.figure(figsize=(9,7))
plt.xlabel('Component 1')
plt.ylabel('Component 2')
for k,c in [(0, 'purple'), (1, 'red')]:
    subset = df_final[national_processed['CONTROL']==k]
    plt.scatter(x=subset['comp_1'],
                y=subset['comp_2'],
                s=150, alpha=.5,
                color=c, label=k )
plt.legend()
plt.show()

# %% [markdown]
# # Stretch Goals
#
# ## 1) Perform further data exploration on the HADS national dataset (the version before we one-hot encoded it) Make scatterplots and see if you can see any resemblance between the original scatterplots and the plot of the principal components that you made in 7.1.
#
# (You may or may not not see very much resemblance depending on the variables you choose, and that's ok!)
#
# ## 2) Study "Scree Plots" and then try and make one for your PCA dataset. How many principal conponents do you need to retain in order for your PCs to contain 90% of the explained variance?
#
# We will present this topic formally at the beginning of tomorrow's lecture, so if you figure this stretch goal out, you're ahead of the game.
#
# ## 3) Explore further the intuition behind eigenvalues and eigenvectors by creating your very own eigenfaces:
#
# Prioritize self-study over this stretch goal if you are not semi-comfortable with the topics of PCA, Eigenvalues, and Eigenvectors.
#
# ![Eigenfaces](https://i.pinimg.com/236x/1c/f1/01/1cf101a9859437a5d096a04b05be06b4--faces-tattoo.jpg)
#
# You don't necessarily have to use this resource, but this will get you started:
# [Eigenface Tutorial](https://sandipanweb.wordpress.com/2018/01/06/eigenfaces-and-a-simple-face-detector-with-pca-svd-in-python/)
